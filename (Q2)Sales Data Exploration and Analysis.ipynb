# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

df = pd.read_csv('Sales_Transactions_Dataset_Weekly.csv')
df_productOnly = df[df.columns[0:54]]
#df_productOnly = df.drop(df.columns[55:107], axis=0, inplace=True)

# %%
print(df_productOnly.describe().T)
# Out:
#      count       mean        std  min  25%  50%   75%   max
# W0   811.0   8.902589  12.067163  0.0  0.0  3.0  12.0  54.0
# W1   811.0   9.129470  12.564766  0.0  0.0  3.0  12.0  53.0
# W2   811.0   9.389642  13.045073  0.0  0.0  3.0  12.0  56.0
# W3   811.0   9.717633  13.553294  0.0  0.0  4.0  13.0  59.0
# W4   811.0   9.574599  13.095765  0.0  0.0  4.0  13.0  61.0
# W5   811.0   9.466091  12.823195  0.0  0.0  3.0  12.5  52.0
# W6   811.0   9.720099  13.347375  0.0  0.0  4.0  13.0  56.0
# W7   811.0   9.585697  13.049138  0.0  0.0  4.0  12.5  62.0
# W8   811.0   9.784217  13.550237  0.0  0.0  4.0  13.0  63.0
# W9   811.0   9.681874  13.137916  0.0  0.0  4.0  13.0  52.0
# W10  811.0   9.790382  13.577685  0.0  0.0  4.0  13.0  56.0
# W11  811.0   9.678175  13.007548  0.0  0.0  4.0  13.0  57.0
# W12  811.0   9.827374  13.366525  0.0  0.0  3.0  13.0  61.0
# W13  811.0   9.686806  13.214865  0.0  0.0  4.0  13.0  55.0
# W14  811.0   9.907522  13.389975  0.0  0.0  4.0  13.0  57.0
# ...

# %%
#calculate the mean and median
df_agg['mn'] = df_productOnly.mean(axis=1)
df_agg['med'] = df_productOnly.median(axis=1)

# %%
#show to products
df_agg.sort_values('mn', ascending=False)
# Out:
#     Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8  ...   W46  W47  W48  \
# 406         P409  42  48  38  43  35  39  36  38  49  ...    44   46   46
# 33           P34  47  42  24  55  42  23  41  51  45  ...    46   34   34
# 177         P178  35  34  40  36  45  37  43  47  34  ...    37   38   42
# 134         P135  38  32  36  37  42  33  56  37  39  ...    34   39   44
# 42           P43  28  43  40  43  54  33  39  30  38  ...    41   43   35
# 189         P190  54  41  51  45  51  46  31  37  38  ...    29   29   31
# 178         P179  44  43  35  36  39  42  31  44  37  ...    55   26   33
# 136         P137  37  41  43  41  40  47  54  30  43  ...    30   33   37
# 91           P92  26  36  56  40  31  44  37  40  38  ...    40   29   34
# 37           P38  37  36  43  52  61  50  35  52  49  ...    32   28   48
# 172         P173  34  25  42  47  37  40  30  44  37  ...    31   37   36
# 173         P174  37  42  30  43  48  44  47  27  43  ...    29   44   32
# ...

# %%
for diff in df_agg['Product_Code']:
    df_agg['dff'] = df_agg['W51']-df_agg['W0']

# %%
df_agg.sort_values('dff', ascending=False)
# Out:
#     Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8 ...   W47  W48  W49  W50  \
# 407         P410   6  13  16   9  18  16  16  12  22 ...    20   22   22   18
# 491         P494   6  13  12  15  16  19   9  18  11 ...    16    9    8    8
# 403         P406   6  12  17  15  14  18  11  17  14 ...    12   11   17   16
# 612         P615  17  16  19  20  19  19  29  35  15 ...    30   29   31   34
# 523         P526   9  13  15  18  15  10  10  17  20 ...    11   17   16   16
# 129         P130  19  53  43  41  39  46  45  31  50 ...    26   31   29   26
# 535         P538   7   7  13  14  11  11  13  17  15 ...    15   11   16   18
# 504         P507  11  27  11  22   9  15  18  21  18 ...    14   13   22   19
# 799         P808   0   3   3   3   1   2   3   2   3 ...     1    5    5    7
# 14           P15  19  45  47  42  29  44  43  36  25 ...    30   30   34   38
# 261         P262  25  31  33  23  38  34  31  31  38 ...    30   29   52   43
# ...
