# %%
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import names, stopwords, words
from nltk.corpus import stopwords
from nltk.tokenize import * 
from textblob import TextBlob

df = pd.read_csv('data job posts.csv')
df['jobpost'].tail()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\siti.nadiyah\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\siti.nadiyah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 18996    Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...
# 18997    "Coca-Cola Hellenic Bottling Company Armenia" ...
# 18998    "Coca-Cola Hellenic Bottling Company Armenia" ...
# 18999    San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...
# 19000    "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...
# Name: jobpost, dtype: object

# %%
df['ApplicationDate'] = df['jobpost'].str.extract(re.compile(r"(\d\d [a-zA-Z]+ \d\d\d\d)"), expand=True)

# %%
df['ApplicationDate'].tail()
# Out:
# 18996    29 December 2015
# 18997    30 December 2015
# 18998    30 December 2015
# 18999    30 December 2015
# 19000    30 December 2015
# Name: ApplicationDate, dtype: object

# %%
df['Duration'] = df['jobpost'].str.extract(re.compile(r"(\d [a-zA-Z]+)"), expand=True)

# %%
df['Duration'].tail()
# Out:
# 18996     5 years
# 18997    3 months
# 18998    3 months
# 18999      1 year
# 19000      1 year
# Name: Duration, dtype: object

# %%
df['title'] = df['jobpost'].str.extract(re.compile(r"(?s)TITLE\s*:\s*(.*)(?:$)"))

# %%
df['title'].tail()
# Out:
# 18996    Senior Creative UX/ UI Designer\r\n\r\n\r\nTER...
# 18997    Category Development Manager\r\n\r\n\r\nTERM: ...
# 18998    Operational Marketing Manager\r\n\r\n\r\nTERM:...
# 18999    Head of Online Sales Department\r\n\r\n\r\nDUR...
# 19000    Lawyer in Legal Department\r\n\r\n\r\nTERM:  F...
# Name: title, dtype: object

# %%
df['Location'] = df['jobpost'].str.extract(re.compile(r"(?s)LOCATION:(.*)(?=\r)"))
df['Location'].tail()
df['Responsibility'] = df['jobpost'].str.extract(re.compile(r"(?s)JOB RESPONSIBILITIES:(.*)(?=\r)"))
df['Responsibility'].tail()
# Out:
# 18996    \r\n- Work closely with product and business t...
# 18997    \r\n- Establish and manage Category Management...
# 18998      \r\n- Develop, establish and maintain market...
# 18999      \r\n- Handle the project activites of the on...
# 19000    \r\n- Properly provide internal legal services...
# Name: Responsibility, dtype: object

# %%
#Identify the company with the most number of job ads in the past 2 years
df[df.Year >= 2014].groupby(['Company','Year']).size().reset_index().sort_values([0,'Year'], ascending = False)
# Out:
#                                                 Company  Year   0
# 834           Mentor Graphics Development Services CJSC  2014  47
# 258                                       ArmenTel CJSC  2014  45
# 907                                 Orange Armenia CJSC  2014  45
# 392                                   Career Center NGO  2015  36
# 835           Mentor Graphics Development Services CJSC  2015  36
# 29    "Coca-Cola Hellenic Bottling Company Armenia" ...  2015  34
# 259                                       ArmenTel CJSC  2015  33
# 1244                               World Vision Armenia  2014  32
# 446                                  Converse Bank CJSC  2015  30
# 731                                       Joomag AM LLC  2015  30
# 932                                         PicsArt LLC  2015  30
# 354                                    BetArchitect LLC  2015  28
# 1158              Tumo Center for Creative Technologies  2015  28
# ...

# %%
#Identify the month with the largest number of job ads over the years
large_ads = df.groupby(['Month']).size()
large_ads.sort_values(ascending=False)
# Out:
# Month
# 3     1702
# 2     1665
# 6     1662
# 9     1652
# 10    1637
# 8     1613
# 7     1595
# 5     1580
# 11    1573
# 4     1466
# 12    1432
# 1     1424
# dtype: int64

# %%
stopwds = stopwords.words('english')
def stop_words(string):
    if string is not None:  
        stop_words = set(stopwords.words('english'))
        word_tokens = word_tokenize(string) 
        string = [w for w in word_tokens if not w in stop_words] 
        string = [] 
        
        for w in word_tokens: 
            if w not in stop_words: 
                filtered_sentence.append(w) 
            else:
                string = ''
                return string

# %%
df['Responsibility'] = df['Responsibility'].apply(stop_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-269-0ee20ba77789> in <module>
# ----> 1 df['Responsibility'] = df['Responsibility'].apply(stop_words)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-268-8a96328e7d9b> in stop_words(string)
#       9         for w in word_tokens:
#      10             if w not in stop_words:
# ---> 11                 filtered_sentence.append(w)
#      12             else:
#      13                 string = ''
#
# ...
